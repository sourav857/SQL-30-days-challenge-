# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('062300bb00c149bcbde39912618ac208','e15238ef44534faeafa8f24a43e2d087'))

# %%
# https://open.spotify.com/playlist/1EVE9kOZ2i4171hNdvWVhU
tracks=spotify.playlist_tracks('1EVE9kOZ2i4171hNdvWVhU')

# %%
type(tracks)
# Out:
# dict

# %%
tracks.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(tracks)
# Out:
# 7

# %%
tracks['items'][99].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
tracks
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1EVE9kOZ2i4171hNdvWVhU/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-02-10T09:07:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/redmusiccompany'},
#     'href': 'https://api.spotify.com/v1/users/redmusiccompany',
#     'id': 'redmusiccompany',
#     'type': 'user',
#     'uri': 'spotify:user:redmusiccompany'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#        'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#        'id': '22wbnEMDvgVIAGdFeek6ET',
#        'name': 'Benson Boone',
#        'type': 'artist',
#        'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BO',
#       'BR',
#       'BG',
# ...

# %%
track=tracks['items'][0]

# %%
track['track']['name']
# Out:
# 'Beautiful Things'

# %%
track['added_by']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/user/redmusiccompany'},
#  'href': 'https://api.spotify.com/v1/users/redmusiccompany',
#  'id': 'redmusiccompany',
#  'type': 'user',
#  'uri': 'spotify:user:redmusiccompany'}

# %%
track['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])
