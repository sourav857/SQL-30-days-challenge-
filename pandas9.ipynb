# %% [markdown]
# # Note : use the orders dataset for below problems:
#
# # 1- create a new column in the orders dataframe with name profit_flag. Set its value as 1 if profit is greater than 0 else set 0.
#
# # 2- in the orders data frame rename column names to upper case ..eg order_id should be ORDER_ID
#
# # 3- again change the column names back to lower case
#
# # 4- sort the dataframe column by profit in descending order
#
# # 5- sort the dataframe column by sales in ascending order , in case of a tie it should be sorted by profit in descending order
#
# # 6- reset the index to original state
#
# # 7- create a column as profit_category . sets it value as below:
#
# # if profit < 0 then 'loss'
# # if profit between 0 and 100 then 'low profit'
# # if profit between 100 and 500 then 'medium profit'
# # else high profit
#
# # 8- create a new column sales_profit_ratio and set its value as (profit/sales)*100
#
# # 9- find all the orders where customer name starts with 'D' and ends with 'e'
#
# # 10- create a new column order_year and populate it with year of order_date. ( hint : use the series objects slice method )
#
# # 11 - delete column sales_profit_ratio from the dataframe
#
# # 12- delete all the rows where profit is negative

# %%
import pandas as pd
df=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
df.loc[df['profit']>0,'profit_flag']=1
df.loc[df['profit']<=0,'profit_flag']=0

# %%
print(df)
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit  profit_flag
# 0          Technology  TEC-PH-10002075  377.970  109.6113          1.0
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354          0.0
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696          1.0
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257          1.0
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288          1.0
# ...               ...              ...      ...       ...          ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696          1.0
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896          1.0
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812          1.0
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640          1.0
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492          0.0
#
# [5009 rows x 9 columns]

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit  profit_flag
# 0          Technology  TEC-PH-10002075  377.970  109.6113          1.0
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354          0.0
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696          1.0
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257          1.0
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288          1.0
# ...               ...              ...      ...       ...          ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696          1.0
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896          1.0
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812          1.0
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640          1.0
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492          0.0
#
# [5009 rows x 9 columns]

# %%
# 2- in the orders data frame rename column names to upper case ..eg order_id should be ORDER_ID

# %%
df=df.columns.str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df=df.columns.str.upper()
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
df
# Out:
# Index(['ORDER_ID', 'ORDER_DATE', 'CUSTOMER_NAME', 'CITY', 'CATEGORY',
#        'PRODUCT_ID', 'SALES', 'PROFIT', 'PROFIT_FLAG'],
#       dtype='object')

# %%
# 3- again change the column names back to lower case

# %%
df.columns.str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.columns.str.lower()
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
df.columns=df.columns.str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.columns=df.columns.str.upper()
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
df.columns = df.columns.str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.columns = df.columns.str.upper()
#
# AttributeError: 'Index' object has no attribute 'columns'

# %%
import pandas as pd
df=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')

# %%
df.columns.str.upper()
# Out:
# Index(['ORDER_ID', 'ORDER_DATE', 'CUSTOMER_NAME', 'CITY', 'CATEGORY',
#        'PRODUCT_ID', 'SALES', 'PROFIT'],
#       dtype='object')

# %%
df.columns=df.columns.str.upper()

# %%
df
# Out:
#             ORDER_ID  ORDER_DATE      CUSTOMER_NAME           CITY  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              CATEGORY       PRODUCT_ID    SALES    PROFIT
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
#- sort the dataframe column by profit in descending order

# %%
df.sort_values(by='profit',ascending=False)
# Out:
#             order_id  order_date     customer_name           city  \
# 4126  CA-2021-166709  2021-11-17      Hunter Lopez         Newark
# 1968  CA-2020-117121  2020-12-17     Adrian Barton        Detroit
# 547   CA-2018-145541  2018-12-14  Tom Boeckenhauer  New York City
# 3521  CA-2021-135909  2021-10-13         Jane Waco     Sacramento
# 4730  US-2021-102183  2021-08-21         Pete Kriz  New York City
# ...              ...         ...               ...            ...
# 1329  CA-2019-140025  2019-04-07      Peter Fuller    San Antonio
# 4821  US-2021-120390  2021-10-19     Tracy Hopkins     Burlington
# 4458  US-2019-150630  2019-09-17   Tracy Blumstein   Philadelphia
# 1020  CA-2019-116638  2019-01-28       Joseph Holt        Concord
# 4829  US-2021-122714  2021-12-07     Henry Goldwyn        Chicago
#
#              category       product_id      sales     profit
# 4126       Technology  TEC-CO-10004722  10499.970  5039.9856
# 1968  Office Supplies  OFF-BI-10000545   9892.740  4946.3700
# 547        Technology  TEC-MA-10001127   6999.960  2239.9872
# 3521  Office Supplies  OFF-BI-10003527   5083.960  1906.4850
# 4730  Office Supplies  OFF-BI-10001359   4305.552  1453.1238
# ...               ...              ...        ...        ...
# 1329  Office Supplies  OFF-AP-10002651    463.248 -1181.2824
# 4821  Office Supplies  OFF-BI-10004995   1633.188 -1306.5504
# 4458        Furniture  FUR-BO-10004834   3083.430 -1665.0522
# 1020        Furniture  FUR-TA-10000198   4297.644 -1862.3124
# 4829  Office Supplies  OFF-BI-10001120   1889.990 -2929.4845
#
# [5009 rows x 8 columns]

# %%
# 5- sort the dataframe column by sales in ascending order , in case of a tie it should be sorted by profit in descending order

# %%
df.sort_values(by=['sales','profit'],ascending=[True,False],inplace=True)

# %%
df
# Out:
#             order_id  order_date     customer_name           city  \
# 4731  US-2021-102288  2021-06-19  Zuschuss Carroll        Houston
# 3293  CA-2021-124114  2021-03-02    Roland Schwarz           Waco
# 2771  CA-2020-168361  2020-06-21       Ken Brennan        Chicago
# 162   CA-2018-112403  2018-03-31     Jas O'Carroll   Philadelphia
# 4315  US-2018-152723  2018-09-26     Henry Goldwyn       Mesquite
# ...              ...         ...               ...            ...
# 540   CA-2018-144624  2018-11-19       John Murray      Jamestown
# 3521  CA-2021-135909  2021-10-13         Jane Waco     Sacramento
# 547   CA-2018-145541  2018-12-14  Tom Boeckenhauer  New York City
# 1968  CA-2020-117121  2020-12-17     Adrian Barton        Detroit
# 4126  CA-2021-166709  2021-11-17      Hunter Lopez         Newark
#
#              category       product_id      sales     profit
# 4731  Office Supplies  OFF-AP-10002906      0.444    -1.1100
# 3293  Office Supplies  OFF-BI-10004022      0.556    -0.9452
# 2771  Office Supplies  OFF-BI-10003727      0.836    -1.3376
# 162   Office Supplies  OFF-BI-10003529      0.852    -0.5964
# 4315  Office Supplies  OFF-BI-10003460      0.876    -1.4016
# ...               ...              ...        ...        ...
# 540        Technology  TEC-PH-10002885   4548.810  1228.1787
# 3521  Office Supplies  OFF-BI-10003527   5083.960  1906.4850
# 547        Technology  TEC-MA-10001127   6999.960  2239.9872
# 1968  Office Supplies  OFF-BI-10000545   9892.740  4946.3700
# 4126       Technology  TEC-CO-10004722  10499.970  5039.9856
#
# [5009 rows x 8 columns]

# %% [markdown]
# # 6- reset the index to original state

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %% [markdown]
# # 7- create a column as profit_category . sets it value as below:
#
# # if profit < 0 then 'loss'
# # if profit between 0 and 100 then 'low profit'
# # if profit between 100 and 500 then 'medium profit'
# # else high profit

# %%
df.loc[df['profit']<0,'profit_category']='Loss'
df.loc[(df['profit']>0) & (df['profit']<100),'profit_category']='low profit'
df.loc[(df['profit']>100) & (df['profit']<500),'profit_category']='medium profit'
df.loc[(df['profit']>500),'profit_category']='Profit'

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit profit_category
# 0          Technology  TEC-PH-10002075  377.970  109.6113   medium profit
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354            Loss
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696      low profit
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257      low profit
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288      low profit
# ...               ...              ...      ...       ...             ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696      low profit
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896      low profit
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812      low profit
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640      low profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492            Loss
#
# [5009 rows x 9 columns]

# %%
# 8- create a new column sales_profit_ratio and set its value as (profit/sales)*100

# %%
df['sales_profit_ratio']=(df['profit']/df['sales'])*100

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit profit_category  \
# 0          Technology  TEC-PH-10002075  377.970  109.6113   medium profit
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354            Loss
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696      low profit
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257      low profit
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288      low profit
# ...               ...              ...      ...       ...             ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696      low profit
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896      low profit
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812      low profit
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640      low profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492            Loss
#
#       sales_profit_ratio
# 0                  29.00
# 1                 -17.50
# 2                  35.00
# 3                  33.75
# 4                  35.00
# ...                  ...
# 5004               32.50
# 5005               47.00
# 5006               47.00
# 5007               29.00
# 5008              -52.00
#
# [5009 rows x 10 columns]

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit profit_category  \
# 0          Technology  TEC-PH-10002075  377.970  109.6113   medium profit
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354            Loss
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696      low profit
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257      low profit
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288      low profit
# ...               ...              ...      ...       ...             ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696      low profit
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896      low profit
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812      low profit
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640      low profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492            Loss
#
#       sales_profit_ratio
# 0                  29.00
# 1                 -17.50
# 2                  35.00
# 3                  33.75
# 4                  35.00
# ...                  ...
# 5004               32.50
# 5005               47.00
# 5006               47.00
# 5007               29.00
# 5008              -52.00
#
# [5009 rows x 10 columns]

# %% [markdown]
# # 7- create a column as profit_category . sets it value as below:
#
# # if profit < 0 then 'loss'
# # if profit between 0 and 100 then 'low profit'
# # if profit between 100 and 500 then 'medium profit'
# # else high profit

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')
def profit_cat(profit):
    if profit<0:
        return 'loss'
    elif profit<=100:
        return 'low profit'
    elif profit<=500:
        return 'medium profit'
    else:
        return 'high profit'

df['profit_category']=df['profit'].apply(profit_cat)

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit profit_category
# 0          Technology  TEC-PH-10002075  377.970  109.6113   medium profit
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354            loss
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696      low profit
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257      low profit
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288      low profit
# ...               ...              ...      ...       ...             ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696      low profit
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896      low profit
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812      low profit
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640      low profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492            loss
#
# [5009 rows x 9 columns]

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')

# Define a function to categorize the profit
def categorize_profit(profit):
    if profit < 0:
        return 'loss'
    elif profit <= 100:
        return 'low profit'
    elif profit <= 500:
        return 'medium profit'
    else:
        return 'high profit'

# Apply the categorize_profit function to create the 'profit_category' column
df['profit_category'] = df['profit'].apply(categorize_profit)

# Display the modified DataFrame
print(df)
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit profit_category
# 0          Technology  TEC-PH-10002075  377.970  109.6113   medium profit
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354            loss
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696      low profit
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257      low profit
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288      low profit
# ...               ...              ...      ...       ...             ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696      low profit
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896      low profit
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812      low profit
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640      low profit
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492            loss
#
# [5009 rows x 9 columns]

# %%
# 9- find all the orders where customer name starts with 'D' and ends with 'e'

# %%
df['customer_name']=df['customer_name'].str.startswith('D')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df['customer_name']=df['customer_name'].str.startswith('D')
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')
res=df[df['customer_name'].str.startswith('D') & ]df['customer_name'].str.startswith('E')
res
# Out:
#             order_id  order_date   customer_name            city  \
# 0     CA-2018-100006  2018-09-07     Dennis Kane   New York City
# 11    CA-2018-100881  2018-03-28   Daniel Raglin     Albuquerque
# 14    CA-2018-100972  2018-11-19   Dennis Bolton  Salt Lake City
# 16    CA-2018-101175  2018-12-09    Dario Medina            Mesa
# 30    CA-2018-102274  2018-11-21   Dave Hallsten        Richmond
# ...              ...         ...             ...             ...
# 4954  US-2021-155299  2021-06-08    Dorris liebe        Pasadena
# 4965  US-2021-158512  2021-01-12   Dianna Arnett      Washington
# 4968  US-2021-159205  2021-03-31     Daniel Byrd       Henderson
# 4979  US-2021-162558  2021-10-02     Dean percer       Knoxville
# 4986  US-2021-164147  2021-02-02  Dorothy Wardle        Columbus
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 11         Technology  TEC-PH-10003273  302.376   22.6782
# 14    Office Supplies  OFF-PA-10000357  166.440   79.8912
# 16    Office Supplies  OFF-ST-10004950  100.704   -1.2588
# 30    Office Supplies  OFF-AR-10002833    5.460    1.4742
# ...               ...              ...      ...       ...
# 4954  Office Supplies  OFF-AP-10002203    1.624   -4.4660
# 4965        Furniture  FUR-FU-10004973   37.680   15.8256
# 4968        Furniture  FUR-FU-10001591   61.000   25.6200
# 4979        Furniture  FUR-FU-10002364   11.808    1.3284
# 4986  Office Supplies  OFF-FA-10002780   21.456    6.9732
#
# [375 rows x 8 columns]

# %%
import pandas as pd

# Read the 'orders.txt' file into a DataFrame
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')

# Filter the DataFrame for customer names starting with 'D' and ending with 'e'
filtered_orders = df[df['customer_name'].str.endswith('D')]

# Display the filtered orders
print(filtered_orders)
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, customer_name, city, category, product_id, sales, profit]
# Index: []

# %%
 # create a new column order_year and populate it with year of order_date. ( hint : use the series objects slice method )

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
df['new_year']=df['order_date'].str.slice(0,4)

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit new_order_date
# 0          Technology  TEC-PH-10002075  377.970  109.6113           2018
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354           2018
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696           2018
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257           2018
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288           2018
# ...               ...              ...      ...       ...            ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696           2021
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896           2021
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812           2021
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640           2021
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492           2021
#
# [5009 rows x 9 columns]

# %%
# 11 - delete column sales_profit_ratio from the dataframe

# %%
# 8- create a new column sales_profit_ratio and set its value as (profit/sales)*100

# %%
df[' sales_profit_ratio']=(df['profit']/df['sales'])*100

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit new_order_date  \
# 0          Technology  TEC-PH-10002075  377.970  109.6113           2018
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354           2018
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696           2018
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257           2018
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288           2018
# ...               ...              ...      ...       ...            ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696           2021
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896           2021
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812           2021
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640           2021
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492           2021
#
#        sales_profit_ratio
# 0                   29.00
# 1                  -17.50
# 2                   35.00
# 3                   33.75
# 4                   35.00
# ...                   ...
# 5004                32.50
# 5005                47.00
# 5006                47.00
# 5007                29.00
# 5008               -52.00
#
# [5009 rows x 10 columns]

# %%
df.drop(columns=['sales_profit_ratio'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 df.drop(columns=['sales_profit_ratio'],inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['sales_profit_ratio'] not found in axis"

# %%
df.drop(columns=['sales_profit_ratio'], inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df.drop(columns=['sales_profit_ratio'], inplace= True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['sales_profit_ratio'] not found in axis"

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')

df['sales_profit_ratio']=(df['profit']/df['sales'])*100
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit  sales_profit_ratio
# 0          Technology  TEC-PH-10002075  377.970  109.6113               29.00
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354              -17.50
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696               35.00
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257               33.75
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288               35.00
# ...               ...              ...      ...       ...                 ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696               32.50
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896               47.00
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812               47.00
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640               29.00
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492              -52.00
#
# [5009 rows x 9 columns]

# %%
df.drop(columns=['sales_profit_ratio'])
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1           Furniture  FUR-TA-10003715  502.488  -87.9354
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# ...               ...              ...      ...       ...
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
# 5008        Furniture  FUR-BO-10001519   87.210  -45.3492
#
# [5009 rows x 8 columns]

# %%
# 12- delete all the rows where profit is negative

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')

# %%
df=df[df['profit']>=0]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df=df[df['profit']>=0]
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'profit'

# %%
df = pd.read_csv('C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt', delimiter=',')
df=df[df['profit']>=0]
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# 5     CA-2018-100391  2018-05-25      Barry Weirich  New York City
# ...              ...         ...                ...            ...
# 5002  US-2021-168613  2021-10-08        Gary McGarr  New York City
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 2     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4     Office Supplies  OFF-FA-10000611    2.368    0.8288
# 5     Office Supplies  OFF-PA-10001471   14.620    6.7252
# ...               ...              ...      ...       ...
# 5002        Furniture  FUR-CH-10002372  145.764    3.2392
# 5004  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 5005  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 5006  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 5007  Office Supplies  OFF-AP-10001947   91.600   26.5640
#
# [3940 rows x 8 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 2     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 3     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# 4     CA-2018-100391  2018-05-25      Barry Weirich  New York City
# ...              ...         ...                ...            ...
# 3935  US-2021-168613  2021-10-08        Gary McGarr  New York City
# 3936  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 3937  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 3938  US-2021-169488  2021-09-07       Allen Armold     Providence
# 3939  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# 1     Office Supplies  OFF-PA-10000176   91.056   31.8696
# 2     Office Supplies  OFF-BI-10000343    3.928    1.3257
# 3     Office Supplies  OFF-FA-10000611    2.368    0.8288
# 4     Office Supplies  OFF-PA-10001471   14.620    6.7252
# ...               ...              ...      ...       ...
# 3935        Furniture  FUR-CH-10002372  145.764    3.2392
# 3936  Office Supplies  OFF-BI-10002393   18.368    5.9696
# 3937  Office Supplies  OFF-AR-10003602   11.680    5.4896
# 3938  Office Supplies  OFF-PA-10000157   39.960   18.7812
# 3939  Office Supplies  OFF-AP-10001947   91.600   26.5640
#
# [3940 rows x 8 columns]
