# %%
# note : use the orders and returns dataset 

# 1- write a program to get category wise sales of orders that were not returned

# 2- write a program to get city wise count of return orders

# 3- write a program to print cities where we have all 3 kinds of returns (others,bad quality,wrong items)

# 4- write a program to find cities where not even a single order was returned.

# 5- write a program to find top 3 cities by sales

# 6- write a program to get order ids whos return reason is not known (nan)

# 7- write a program to fill unknown return reason to a default value 'others'

# 8- write a program to find avg sales and avg profit for each category

# %%
import pandas as pd
df=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
df
# Out:
#             order_id  order_date      customer_name           city  \
# 0     CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 1     CA-2018-100090  2018-07-08         Ed Braxton  San Francisco
# 2     CA-2018-100293  2018-03-14   Neil Französisch   Jacksonville
# 3     CA-2018-100328  2018-01-28    Jasper Cacioppo  New York City
# 4     CA-2018-100363  2018-04-08        Jim Mitchum       Glendale
# ...              ...         ...                ...            ...
# 5004  US-2021-168802  2021-11-03      Jack O'Briant        Seattle
# 5005  US-2021-169320  2021-07-23     Lena Hernandez        Elkhart
# 5006  US-2021-169488  2021-09-07       Allen Armold     Providence
# 5007  US-2021-169502  2021-08-28  Matthew Grinstein      Milwaukee
# 5008  US-2021-169551  2021-07-07          Rob Lucas   Philadelphia
#
#              category       product_id    sales    profit
# 0          Technology  TEC-PH-10002075  377.970  109.6113
# ...

# %%
import pandas as pd
df=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')
df
# Out:
#            Order Id Return Reason
# 0    CA-2020-104689   Wrong Items
# 1    CA-2020-105081   Wrong Items
# 2    CA-2020-105291   Wrong Items
# 3    CA-2020-105585   Wrong Items
# 4    CA-2020-106950   Wrong Items
# ..              ...           ...
# 291  US-2021-136679        Others
# 292  US-2021-147886        Others
# 293  US-2021-147998   Wrong Items
# 294  US-2021-151127   Wrong Items
# 295  US-2021-155999   Wrong Items
#
# [296 rows x 2 columns]

# %%
pd.set_option('display.max_columns', 100)

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\tooso\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
import pandas as pd

# Set maximum number of rows and columns displayed
pd.set_option('display.max_rows', 1000)  # None means display all rows
  # None means display all columns

# Now load your data and display it
data = df=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')
print(data)
# Out:
#            Order Id Return Reason
# 0    CA-2020-104689   Wrong Items
# 1    CA-2020-105081   Wrong Items
# 2    CA-2020-105291   Wrong Items
# 3    CA-2020-105585   Wrong Items
# 4    CA-2020-106950   Wrong Items
# 5    CA-2020-109806   Wrong Items
# 6    CA-2020-109869   Wrong Items
# 7    CA-2020-111682   Wrong Items
# 8    CA-2020-112123   Wrong Items
# 9    CA-2020-112340   Wrong Items
# 10   CA-2020-113341   Wrong Items
# 11   CA-2020-114307           NaN
# 12   CA-2020-114727   Wrong Items
# 13   CA-2020-115917   Wrong Items
# 14   CA-2020-116547   Wrong Items
# 15   CA-2020-116736   Wrong Items
# 16   CA-2020-118311   Wrong Items
# 17   CA-2020-118500   Wrong Items
# 18   CA-2020-118899   Wrong Items
# 19   CA-2020-120873   Wrong Items
# 20   CA-2020-123526   Wrong Items
# 21   CA-2020-124527   Wrong Items
# 22   CA-2020-126529   Wrong Items
# 23   CA-2020-126732   Wrong Items
# 24   CA-2020-128671   Wrong Items
# 25   CA-2020-130477   Wrong Items
# ...

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
no_null_values=merge.dropna(how='any')
no_null_values.groupby('category')['sales'].sum()
# merge.groupby('category')['sales'].sum()
# Out:
# category
# Furniture          45457.7759
# Office Supplies    14080.5250
# Technology          6006.1900
# Name: sales, dtype: float64

# %%
# 2- write a program to get city wise count of return orders

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
no_null_values=merge.dropna(how='any')
new=merge['city'].value_counts()
# Out:
# city
# New York City        450
# Los Angeles          384
# San Francisco        265
# Philadelphia         265
# Seattle              212
# Houston              188
# Chicago              171
# Columbus             111
# San Diego             88
# Dallas                80
# Springfield           73
# Jacksonville          61
# Detroit               53
# Newark                45
# Richmond              41
# Jackson               37
# Aurora                35
# Miami                 34
# Columbia              33
# Long Beach            33
# Arlington             31
# Phoenix               29
# Lakewood              29
# Louisville            29
# Rochester             28
# San Antonio           27
# Lancaster             27
# Fairfield             24
# Charlotte             24
# Milwaukee             23
# Cleveland             21
# Lawrence              21
# Concord               21
# Baltimore             21
# San Jose              20
# Fayetteville          20
# ...

# %%
# 3- write a program to print cities where we have all 3 kinds of returns (others,bad quality,wrong items)

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
res=merge.groupby('city')['Return Reason'].nunique() 
res[res.values==3]

# no_null_values.groupby('category')['sales'].sum()
# Out:
# city
# Los Angeles      3
# New York City    3
# Name: Return Reason, dtype: int64

# %%
res
# Out:
# 531

# %%
#  write a program to find cities where not even a single order was returned.

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
res=merge.groupby('city')['Return Reason'].unique() 
res
# Out:
# city
# Aberdeen                                               [nan]
# Abilene                                                [nan]
# Akron                                                  [nan]
# Albuquerque                               [nan, Bad Quality]
# Alexandria                                             [nan]
# Allen                                                  [nan]
# Allentown                                              [nan]
# Altoona                                                [nan]
# Amarillo                                  [nan, Wrong Items]
# Anaheim                                   [nan, Wrong Items]
# Andover                                                [nan]
# Ann Arbor                                              [nan]
# Antioch                                                [nan]
# Apopka                                                 [nan]
# Apple Valley                              [nan, Wrong Items]
# ...

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
merge=merge.groupby('city')['Return Reason'].count()
merge[merge.values==0]
# Out:
# city
# Aberdeen             0
# Abilene              0
# Akron                0
# Alexandria           0
# Allen                0
# Allentown            0
# Altoona              0
# Andover              0
# Ann Arbor            0
# Antioch              0
# Apopka               0
# Appleton             0
# Arlington            0
# Arlington Heights    0
# Arvada               0
# Asheville            0
# Athens               0
# Atlantic City        0
# Auburn               0
# Avondale             0
# Baltimore            0
# Bangor               0
# Bayonne              0
# Baytown              0
# Beaumont             0
# Bedford              0
# Belleville           0
# Bellevue             0
# Bellingham           0
# Bethlehem            0
# Beverly              0
# Billings             0
# Boca Raton           0
# Bolingbrook          0
# Bossier City         0
# Bowling Green        0
# Boynton Beach        0
# Bridgeton            0
# Bristol              0
# ...

# %%
merge=merge.groupby('city')['Return Reason'].count()
merge[merge.values==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 merge=merge.groupby('city')['Return Reason'].count()
#       2 merge[merge.values==0]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Return Reason'

# %%
# 5- write a program to find top 3 cities by sales

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')

# %%
merge.groupby('city')['sales'].sum().sort_values(ascending=False).head(3)
# Out:
# city
# New York City    115073.919
# Los Angeles       79663.299
# San Francisco     52590.648
# Name: sales, dtype: float64

# %%
# 6- write a program to get order ids whos return reason is not known (nan)

# %%
import pandas as pd
# orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

# merge=pd.merge(left=orders,right=returns,how='left',left_on='order_id',right_on='Order Id')
returns[returns['Return Reason'].isnull()]
# Out:
#            Order Id Return Reason
# 11   CA-2020-114307           NaN
# 29   CA-2020-133368           NaN
# 107  CA-2018-105270           NaN
# 142  CA-2018-164721           NaN
# 149  CA-2019-105158           NaN

# %%
 # write a program to fill unknown return reason to a default value 'others'

# %%
import pandas as pd
# orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
returns= pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/returns.txt",delimiter=',')

# %%
returns['Return Reason'].fillna('others',inplace=True)

# %%
returns
# Out:
#            Order Id Return Reason
# 0    CA-2020-104689   Wrong Items
# 1    CA-2020-105081   Wrong Items
# 2    CA-2020-105291   Wrong Items
# 3    CA-2020-105585   Wrong Items
# 4    CA-2020-106950   Wrong Items
# 5    CA-2020-109806   Wrong Items
# 6    CA-2020-109869   Wrong Items
# 7    CA-2020-111682   Wrong Items
# 8    CA-2020-112123   Wrong Items
# 9    CA-2020-112340   Wrong Items
# 10   CA-2020-113341   Wrong Items
# 11   CA-2020-114307        others
# 12   CA-2020-114727   Wrong Items
# 13   CA-2020-115917   Wrong Items
# 14   CA-2020-116547   Wrong Items
# 15   CA-2020-116736   Wrong Items
# 16   CA-2020-118311   Wrong Items
# 17   CA-2020-118500   Wrong Items
# 18   CA-2020-118899   Wrong Items
# 19   CA-2020-120873   Wrong Items
# 20   CA-2020-123526   Wrong Items
# 21   CA-2020-124527   Wrong Items
# 22   CA-2020-126529   Wrong Items
# 23   CA-2020-126732   Wrong Items
# 24   CA-2020-128671   Wrong Items
# 25   CA-2020-130477   Wrong Items
# ...

# %%
# 8- write a program to find avg sales and avg profit for each category

# %%
import pandas as pd
orders=pd.read_csv("C:/Program Files/JetBrains/PyCharm 2023.3.4/orders.txt",delimiter=',')
orders.groupby('category').agg({'sales':'mean','profit':'mean'})
# Out:
#                       sales     profit
# category
# Furniture        356.212758   9.813403
# Office Supplies  107.680040  18.906134
# Technology       382.705186  75.452770
